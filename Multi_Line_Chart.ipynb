# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter
from matplotlib.dates import DateFormatter

from scipy import stats

# %%
employ= pd.read_csv('data/unemployment.csv')
date= pd.DataFrame(data=pd.unique(employ['date']), columns=['date'])
industry= pd.unique(employ['industry'])

for i in range(industry.shape[0]):
    by_industry= pd.DataFrame(data=np.asarray((employ.loc[employ['industry'] == industry[i]])['unemployed']), 
                              columns=[industry[i]])
    
    date= pd.concat([date, by_industry], axis=1)
    
x_date= np.asarray(date['date'])

y_values = [np.asarray((date.T).iloc[i,0:date.shape[0]], dtype=int) for i in range(1,date.shape[1])]

# %%
industry
# Out:
# array(['Wholesale and Retail Trade', 'Manufacturing',
#        'Leisure and hospitality', 'Business services', 'Construction',
#        'Education and Health', 'Government', 'Finance', 'Self-employed',
#        'Other', 'Transportation and Utilities', 'Information',
#        'Agriculture', 'Mining and Extraction'], dtype=object)

# %%
import matplotlib.colors as mcolors

cmap= list((mcolors.TABLEAU_COLORS).values())

# %%
fig, ax= plt.subplots(figsize=(13, 7))

for i in range(1,4):
    ax.plot(pd.to_datetime(date['date']), y_values[i-1], linewidth=3, label=industry[i-1], 
            color=cmap[(i-1)%10])

ax.legend(ncol=5, loc='center', bbox_to_anchor=(0.5, 1.08), prop={'size': 12})

plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
ax.spines[['right', 'top']].set_visible(False)
ax.spines[['bottom','left']].set_linewidth(2)
ax.tick_params(length=5, width=2)
ax.xaxis.set_major_formatter(date_format)
ax.set_xlabel('Time', fontsize=15)
ax.set_ylabel('Y-axis data', fontsize=15)

plt.savefig("series_3.svg")

# %%
date_format= DateFormatter('%Y')

fig, ax= plt.subplots(figsize=(13, 7))

for i in range(1,11):
    ax.plot(pd.to_datetime(date['date']), y_values[i-1], linewidth=3, label=industry[i-1], 
            color=cmap[(i-1)%10])

ax.legend(ncol=5, loc='center', bbox_to_anchor=(0.5, 1.08), prop={'size': 12})

plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
ax.spines[['right', 'top']].set_visible(False)
ax.spines[['bottom','left']].set_linewidth(2)
ax.tick_params(length=5, width=2)
ax.xaxis.set_major_formatter(date_format)
ax.set_xlabel('Time', fontsize=15)
ax.set_ylabel('Y-axis data', fontsize=15)

plt.savefig("series_10.svg")
